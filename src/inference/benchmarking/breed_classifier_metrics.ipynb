# %%
from pathlib import Path
from ultralytics import YOLO
# root of where repo was cloned
base_path = Path.home() / "Desktop" / "Senior Year" / "Super_Senior" / "Furry Friends" 
# model path
model_path = base_path / "Furry_Friends" / "models" / "breed" / "breed_model_0.pt"

model = YOLO(model_path)

# %%
metrics = model.val(split="test")
print(f"Top 1 Accuracy: {metrics.top1}")
print(f"Top 5 Accuracy: {metrics.top5}")
# Out:
# Ultralytics 8.3.228  Python-3.13.5 torch-2.9.1+cu126 CUDA:0 (NVIDIA RTX 500 Ada Generation Laptop GPU, 4094MiB)
# ERROR train: C:\Users\arbsh\Desktop\Senior Year\Super_Senior\Furry Friends\datasets\pets_breed_split\train... found 19528 images in 144 classes (requires 146 classes, not 144)
# ERROR val: C:\Users\arbsh\Desktop\Senior Year\Super_Senior\Furry Friends\datasets\pets_breed_split\val... found 4132 images in 144 classes (requires 146 classes, not 144)
# ERROR test: C:\Users\arbsh\Desktop\Senior Year\Super_Senior\Furry Friends\datasets\pets_breed_split\test... found 4310 images in 144 classes (requires 146 classes, not 144)
# test: Fast image access  (ping: 0.00.0 ms, read: 950.8701.6 MB/s, size: 89.5 KB)
# test: Scanning C:\Users\arbsh\Desktop\Senior Year\Super_Senior\Furry Friends\datasets\pets_breed_split\test... 4310 images, 0 corrupt: 100% ━━━━━━━━━━━━ 4310/4310 7.8Mit/s 0.0s0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 270/270 33.9it/s 8.0s<0.0s
#                    all      0.819      0.972
# Speed: 0.1ms preprocess, 1.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\arbsh\Desktop\Senior Year\Super_Senior\Furry Friends\Furry_Friends\src\inference\benchmarking\runs\classify\val3
# Top 1 Accuracy: 0.8185614943504333
# Top 5 Accuracy: 0.972389817237854
